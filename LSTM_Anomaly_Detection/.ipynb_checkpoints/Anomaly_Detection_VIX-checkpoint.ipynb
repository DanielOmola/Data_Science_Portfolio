# %% [markdown]
# # 0.0 - Load Modules, instanciate Random Seed, check Tensor Flow version

# %%
from mypackage import mydataloader as loader
from mypackage import stationarity as st
from mypackage import create_dataset as cd
from mypackage import LSTM_autoencoder as LA
from mypackage import ploter as plt

import calendar
from sklearn.preprocessing import StandardScaler, MinMaxScaler 
import tensorflow as tf
import pandas as pd
# Out:
# WARNING:tensorflow:From C:\Users\danie\GitHub\Portfolio\Data_Science_Portfolio\LSTM_Anomaly_Detection\mypackage\LSTM_autoencoder.py:14: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 0.1 - Data

# %%
path = './data/'
data_spx = loader.get_data(path =path,verbose=True)
# Out:
#  //////////// Initial Data Shape  ////////////
#
# 	 (7180, 7)
#
# //////////// Describe ////////////
#
#           close_spx         year        month  returns_spx    close_vix  \
# count  7180.000000  7180.000000  7180.000000  7180.000000  7180.000000
# mean   1182.637773  2003.739972     6.488440     0.000343    19.317065
# std     576.773716     8.232987     3.429956     0.011065     7.841664
# min     295.460000  1990.000000     1.000000    -0.090350     9.140000
# 25%     757.027500  1997.000000     4.000000    -0.004421    13.630000
# 50%    1166.030000  2004.000000     6.000000     0.000531    17.440001
# 75%    1426.547500  2011.000000     9.000000     0.005540    22.730000
# max    2872.870000  2018.000000    12.000000     0.115800    80.860001
#
#        returns_vix
# count  7180.000000
# mean      0.002139
# std       0.067521
# min      -0.295727
# 25%      -0.035841
# 50%      -0.003197
# 75%       0.032441
# max       1.155979
#
# //////////// Data Types ////////////
#
#  close_spx      float64
# year             int64
# month            int64
# period          object
# returns_spx    float64
# close_vix      float64
# returns_vix    float64
# dtype: object

# %%
data_spx.head()
# Out:
#             close_spx  year  month  period  returns_spx  close_vix  \
# date
# 1990-01-03     358.76  1990      1  1990_1    -0.002586  18.190001
# 1990-01-04     355.66  1990      1  1990_1    -0.008641  19.219999
# 1990-01-05     352.20  1990      1  1990_1    -0.009728  20.110001
# 1990-01-08     353.79  1990      1  1990_1     0.004514  20.260000
# 1990-01-09     349.62  1990      1  1990_1    -0.011787  22.200001
#
#             returns_vix
# date
# 1990-01-03     0.055104
# 1990-01-04     0.056624
# 1990-01-05     0.046306
# 1990-01-08     0.007459
# 1990-01-09     0.095755

# %% [markdown]
# # 1 - **Check Stationarity**

# %%
st.check_stationarity(data_spx,col='returns_vix')
# Out:
# ADF Statistic: -28.921859
#
# p-value: 0.000000
#
# Critical Values:
#
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567

# %% [markdown]
# # 2 - Find optimal number of steps

# %%
st.get_number_steps(data_spx,'returns_vix')
# Out:
# => Recommanded number of steps for returns_vix : 7

# %% [markdown]
# # 3 - Train/Test split
# * train 95%
# * test 5%

# %%
# /////////////////// Split ////////////////////////
train, test = loader.split_data(data = data_spx, pct_train_test = 0.95)

# %% [markdown]
# # 4 - Scale the Data

# %%
# /////////////////// Scale ////////////////////////
train, test = loader.scale_data(train, test, col = 'returns_spx', scaler = StandardScaler(),verbose = False)
train, test = loader.scale_data(train, test, col = 'returns_vix', scaler = MinMaxScaler(),verbose = False)

# %% [markdown]
# # 5 - Create data sliding windows for train and test sets

# %%
# //////////////// Get the sliding windows ////////////////
X_train, X_test, y_train, y_test = cd.get_data_sequences(train,test,col='returns_vix',TIME_STEPS = 2)

# %% [markdown]
# # 6 - Build the LSTM_autoencoder

# %% [markdown]
# - Instanciate
# - Get the best parameters
# - Train on the best parameter

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 6.1.1 - Instanciate

# %%
X_train, X_test, y_train, y_test = cd.get_data_sequences(train,test,col='returns_vix',TIME_STEPS = 2)
model_VIX = LA.LSTM_autoencoder(train, test)

# %% [markdown]
# ### 6.1.2 - Get the best parameters (no need to run it, already done)

# %%
epoch = 2

nb_hidden_units = [15,15,15,15,15,15,15,15,15,15,
                   20,20,20,20,20,20,20,20,20,20
                   ]
n = len(nb_hidden_units)
nb_epochs=[epoch]*n
TIME_STEPS = [2,3,4,5,10,15,20,25,30,35,
              2,3,4,5,10,15,20,25,30,35
              ]
droupout_rate = [.2]*n
batch_size=[32]*n

LA.get_best_param(model_VIX,train,test,
                    nb_hidden_units = nb_hidden_units,
                    nb_epochs=nb_epochs,
                    TIME_STEPS = TIME_STEPS,
                    droupout_rate = droupout_rate,
                    batch_size=batch_size,
                    col='returns_spx',
                     verbose = False)
# Out:
# 2/20 parameter sets

# %% [markdown]
# ### 6.1.3 - Train the Model on the best parameters

# %%
optimizer = tf.keras.optimizers.Adam(
                                              learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-07, amsgrad=True,
                                              name='Adam')

X_train, X_test, y_train, y_test = cd.get_data_sequences(train,test,col='returns_vix',TIME_STEPS = 2)
model_VIX = LA.LSTM_autoencoder(train, test)
model_VIX.build_model(X_train,nb_hidden_units = 20,optimizer = optimizer,droupout_rate = 0.2,verbose = False)
model_VIX.train_it(X_train, y_train,nb_epochs=10,batch_size=32,verbose = False)
model_VIX.plot_history()
# Out:
# <div>                            <div id="8e34cdf8-6937-46df-af7c-380da47345ac" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8e34cdf8-6937-46df-af7c-380da47345ac")) {                    Plotly.newPlot(                        "8e34cdf8-6937-46df-af7c-380da47345ac",                        [{"mode": "lines", "name": "train loss", "type": "scatter", "y": [0.07021190971136093, 0.04989350959658623, 0.04836389794945717, 0.0477779246866703, 0.04739939793944359, 0.04726901650428772, 0.04698928818106651, 0.04700517654418945, 0.0469847247004509, 0.04691031575202942]}, {"mode": "lines", "name": "validation loss", "type": "scatter", "y": [0.05902434140443802, 0.0578438825905323, 0.05771249905228615, 0.05777012184262276, 0.05765269324183464, 0.05762209743261337, 0.05763450637459755, 0.05771436169743538, 0.05760684609413147, 0.05759996548295021]}],                        {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outl ...

# %% [markdown]
# # 7 - VIX Model : Predict on Train Set and check Error

# %%
model_VIX.predict(X_train)
pred_vix_train = model_VIX.predictions
loss_vix_train = model_VIX.mae_loss

# %% [markdown]
# ### Error distribution Train Set
# > Does help in chosing an anomaly treshold.

# %%
plt.hist(
    data=pd.Series(loss_vix_train.reshape(-1)),
    col=0)
# Out:
# <div>                            <div id="d92e4e0f-3644-4474-b07d-a2f974d55b30" class="plotly-graph-div" style="height:400px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d92e4e0f-3644-4474-b07d-a2f974d55b30")) {                    Plotly.newPlot(                        "d92e4e0f-3644-4474-b07d-a2f974d55b30",                        [{"alignmentgroup": "True", "bingroup": "x", "hovertemplate": "0=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "histogram", "x": [0.07221174252606491, 0.06694902780750392, 0.0375265778674555, 0.0670673044510709, 0.06915914680300655, 0.0633124627613877, 0.17878006312586076, 0.18388236026845917, 0.08101201654659279, 0.04422826187887621, 0.0092962422534624, 0.044956079488148476, 0.1397333024201267, 0.13913788457624857, 0.05337333581309722, 0.027218083863479542, 0.02616157581184142, 0.024162392160594987, 0.027300994958036312, 0.053899861403728794, 0.04771413296066793, 0.019449478266941267, 0.016108196348982612, 0.014407550337834502, 0.012392083014230754, 0.01715925898836415, 0.00948985001364544, 0.02073724750891287, 0.029537885916769896, 0.052902648438825486, 0.10112932887143751, 0.0848924693670807, 0.09542903553948492, 0.09214651488135325, 0.056595693763851235, 0.056847447630714865, 0.0326056110344366, 0.02002562489831644, 0.03520443369796733, 0.015575641192133505, 0.012401704901329413, 0.030430710523066784, 0.05363258709919683, 0.07702425336379173, 0.05490093339966337, 0.0423682094085126, 0.021572133730789422, 0.03173494901042509, 0.062013651480470416, 0.06000666490985418, 0.0580567320500054, 0.05345712747801247, 0.053287694385168144, 0.06318592287647232, 0.11659615119572872, 0.12384535371709107, 0.08005265022135097, 0.06095118069907968, 0.07053203707278594, 0.06957743251045129, 0.0715506033375605, 0.1408627850283468, 0.14035400821588648, 0.09694211886971171, 0.06164643927927299, 0.03317027545615145, 0.03570493787312373, 0.028285928142106148, 0.1201383156190118, 0.15890646604970693, 0.10399328107681233, 0.03545033771839351, 0.06927034879799465, 0.06709857767483665, 0.02522502548795391, 0.04981143947529501, 0.07392925318321553, 0.07870658950303305, 0.035309915260766184, 0.06642649534250084, 0.11577510295941182, 0.09999496733136748, 0.05502903162801684, 0.06797686459473756, 0.059212000018320415, 0.02679127664599215, 0.04662046844713233, 0.03868782436098772, 0.008589451988135044, 0.04297296298782688, 0.054604504494046774, 0.026602033826086835, 0.068563968600275, 0.06415240512165019, 0.011957691961417743, 0.013774787457247167, 0.050257899931797106, 0.055801667809301986, 0.03537627572651145, 0.028017578797860765, 0.05520541525643932, 0.0816910954861802, 0.038871957909846766, 0.006982417109605232, 0.0488866941490311, 0.06976508026006123, 0.06100245037699839, 0.06207610931808674, 0.038207334792392356, 0.06027297962495583, 0.04545169104864814, 0.04296432717839874, 0.03416147011336035, 0.04730662442182737, 0.10627716098328166, 0.13590507596063664, 0.07686280392999065, 0.021174059176923, 0.18780124501847728, 0.23116958151620626, 0.09269254537714158, 0.03231653566753753, 0.01500501594313941, 0.02896721221591328, 0.04810758073793403, 0.03139026806911602, 0.042388470689757374, 0.06408056570242654, 0.03351364937810353, 0.023790563612831828, 0.01634110177253209, 0.019273686050670064, 0.020028384894401757, 0.012066130662109292, 0.009784227050954636, 0.08252199486871756, 0.08133744181904926, 0.09978288813269491, 0.3595741240236293, 0.315905078841175, 0.08628916968365113, 0.04031220277064865, 0.03279532250102879, 0.031886985616855434, 0.005057598430753624, 0.018934059824647437, 0.043759569126517434, 0.2474955139369028, 0.39901444982801726, 0.1798264470541565, 0.12902133711943026, 0.15842769460620437, 0.1021 ...

# %% [markdown]
# # 8 - Anomalies on Train Set
# > Does help in chosing an anomaly treshold.

# %%
anomaly_vix_train = model_VIX.get_anomaly_prediction_df(X_train,set_type='train',THRESHOLD=.3,TIME_STEPS=2,is_spx=False)
plt.plot_loss_tresshold(anomaly_vix_train)
plt.plot_anomalies(anomaly_vix_train,secondary_y='close_spx')
# Out:
# Index([], dtype='object')
# <div>                            <div id="a1f2f3f9-dc74-48f5-9558-0e36425686f9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a1f2f3f9-dc74-48f5-9558-0e36425686f9")) {                    Plotly.newPlot(                        "a1f2f3f9-dc74-48f5-9558-0e36425686f9",                        [{"mode": "lines", "name": "error", "type": "scatter", "x": ["1990-01-05T00:00:00", "1990-01-08T00:00:00", "1990-01-09T00:00:00", "1990-01-10T00:00:00", "1990-01-11T00:00:00", "1990-01-12T00:00:00", "1990-01-15T00:00:00", "1990-01-16T00:00:00", "1990-01-17T00:00:00", "1990-01-18T00:00:00", "1990-01-19T00:00:00", "1990-01-22T00:00:00", "1990-01-23T00:00:00", "1990-01-24T00:00:00", "1990-01-25T00:00:00", "1990-01-26T00:00:00", "1990-01-29T00:00:00", "1990-01-30T00:00:00", "1990-01-31T00:00:00", "1990-02-01T00:00:00", "1990-02-02T00:00:00", "1990-02-05T00:00:00", "1990-02-06T00:00:00", "1990-02-07T00:00:00", "1990-02-08T00:00:00", "1990-02-09T00:00:00", "1990-02-12T00:00:00", "1990-02-13T00:00:00", "1990-02-14T00:00:00", "1990-02-15T00:00:00", "1990-02-16T00:00:00", "1990-02-20T00:00:00", "1990-02-21T00:00:00", "1990-02-22T00:00:00", "1990-02-23T00:00:00", "1990-02-26T00:00:00", "1990-02-27T00:00:00", "1990-02-28T00:00:00", "1990-03-01T00:00:00", "1990-03-02T00:00:00", "1990-03-05T00:00:00", "1990-03-06T00:00:00", "1990-03-07T00:00:00", "1990-03-08T00:00:00", "1990-03-09T00:00:00", "1990-03-12T00:00:00", "1990-03-13T00:00:00", "1990-03-14T00:00:00", "1990-03-15T00:00:00", "1990-03-16T00:00:00", "1990-03-19T00:00:00", "1990-03-20T00:00:00", "1990-03-21T00:00:00", "1990-03-22T00:00:00", "1990-03-23T00:00:00", "1990-03-26T00:00:00", "1990-03-27T00:00:00", "1990-03-28T00:00:00", "1990-03-29T00:00:00", "1990-03-30T00:00:00", "1990-04-02T00:00:00", "1990-04-03T00:00:00", "1990-04-04T00:00:00", "1990-04-05T00:00:00", "1990-04-06T00:00:00", "1990-04-09T00:00:00", "1990-04-10T00:00:00", "1990-04-11T00:00:00", "1990-04-12T00:00:00", "1990-04-16T00:00:00", "1990-04-17T00:00:00", "1990-04-18T00:00:00", "1990-04-19T00:00:00", "1990-04-20T00:00:00", "1990-04-23T00:00:00", "1990-04-24T00:00:00", "1990-04-25T00:00:00", "1990-04-26T00:00:00", "1990-04-27T00:00:00", "1990-04-30T00:00:00", "1990-05-01T00:00:00", "1990-05-02T00:00:00", "1990-05-03T00:00:00", "1990-05-04T00:00:00", "1990-05-07T00:00:00", "1990-05-08T00:00:00", "1990-05-09T00:00:00", "1990-05-10T00:00:00", "1990-05-11T00:00:00", "1990-05-14T00:00:00", "1990-05-15T00:00:00", "1990-05-16T00:00:00", "1990-05-17T00:00:00", "1990-05-18T00:00:00", "1990-05-21T00:00:00", "1990-05-22T00:00:00", "1990-05-23T00:00:00", "1990-05-24T00:00:00", "1990-05-25T00:00:00", "1990-05-29T00:00:00", "1990-05-30T00:00:00", "1990-05-31T00:00:00", "1990-06-01T00:00:00", "1990-06-04T00:00:00", "1990-06-05T00:00:00", "1990-06-06T00:00:00", "1990-06-07T00:00:00", "1990-06-08T00:00:00", "1990-06-11T00:00:00", "1990-06-12T00:00:00", "1990-06-13T00:00:00", "1990-06-14T00:00:00", "1990-06-15T00:00:00", "1990-06-18T00:00:00", "1990-06-19T00:00:00", "1990-06-20T00:00:00", "1990-06-21T00:00:00", "1990-06-22T00:00:00", "1990-06-25T00:00:00", "1990-06-26T00:00:00", "1990-06-27T00:00:00", "1990-06-28T00:00:00", "1990-06-29T00:00:00", "1990-07-02T00:00:00", "1990-07-03T00:00:00", "1990-07-05T00:00:00", "1990-07-06T00:00:00", "1990-07-09T00:00:00", "1990-07-10T00:00:00", "1990-07-11T00:00:00", "1990-07-12T00:00:00", "1990-07-13T00:00:00", "1990-07-16T00:00:00", "1990-07-17T00:00:00", "1990-07-18T00:00:00", "1990-07-19T00:00:00", "1990-07-20T00:00:00", "1990-07-23T00:00:00", "1990-07-24T00:00:00", "1990-07-25T00:00:00", "1990-07-26T00:00:00", "1990-07-27T00:00:00", "1990-07-30T00:00:00", "1990-07-31T00:00:00", "1990-08-01T00:00:00", "1990-08-02T00:00:00", "1990-08-03T00:00:00", "1990-08-06T00:00:00", "1990 ...
# <div>                            <div id="0fdc3429-dd99-4864-b68e-ddc81181acaa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0fdc3429-dd99-4864-b68e-ddc81181acaa")) {                    Plotly.newPlot(                        "0fdc3429-dd99-4864-b68e-ddc81181acaa",                        [{"mode": "lines", "name": "close", "type": "scatter", "x": ["1990-01-05T00:00:00", "1990-01-08T00:00:00", "1990-01-09T00:00:00", "1990-01-10T00:00:00", "1990-01-11T00:00:00", "1990-01-12T00:00:00", "1990-01-15T00:00:00", "1990-01-16T00:00:00", "1990-01-17T00:00:00", "1990-01-18T00:00:00", "1990-01-19T00:00:00", "1990-01-22T00:00:00", "1990-01-23T00:00:00", "1990-01-24T00:00:00", "1990-01-25T00:00:00", "1990-01-26T00:00:00", "1990-01-29T00:00:00", "1990-01-30T00:00:00", "1990-01-31T00:00:00", "1990-02-01T00:00:00", "1990-02-02T00:00:00", "1990-02-05T00:00:00", "1990-02-06T00:00:00", "1990-02-07T00:00:00", "1990-02-08T00:00:00", "1990-02-09T00:00:00", "1990-02-12T00:00:00", "1990-02-13T00:00:00", "1990-02-14T00:00:00", "1990-02-15T00:00:00", "1990-02-16T00:00:00", "1990-02-20T00:00:00", "1990-02-21T00:00:00", "1990-02-22T00:00:00", "1990-02-23T00:00:00", "1990-02-26T00:00:00", "1990-02-27T00:00:00", "1990-02-28T00:00:00", "1990-03-01T00:00:00", "1990-03-02T00:00:00", "1990-03-05T00:00:00", "1990-03-06T00:00:00", "1990-03-07T00:00:00", "1990-03-08T00:00:00", "1990-03-09T00:00:00", "1990-03-12T00:00:00", "1990-03-13T00:00:00", "1990-03-14T00:00:00", "1990-03-15T00:00:00", "1990-03-16T00:00:00", "1990-03-19T00:00:00", "1990-03-20T00:00:00", "1990-03-21T00:00:00", "1990-03-22T00:00:00", "1990-03-23T00:00:00", "1990-03-26T00:00:00", "1990-03-27T00:00:00", "1990-03-28T00:00:00", "1990-03-29T00:00:00", "1990-03-30T00:00:00", "1990-04-02T00:00:00", "1990-04-03T00:00:00", "1990-04-04T00:00:00", "1990-04-05T00:00:00", "1990-04-06T00:00:00", "1990-04-09T00:00:00", "1990-04-10T00:00:00", "1990-04-11T00:00:00", "1990-04-12T00:00:00", "1990-04-16T00:00:00", "1990-04-17T00:00:00", "1990-04-18T00:00:00", "1990-04-19T00:00:00", "1990-04-20T00:00:00", "1990-04-23T00:00:00", "1990-04-24T00:00:00", "1990-04-25T00:00:00", "1990-04-26T00:00:00", "1990-04-27T00:00:00", "1990-04-30T00:00:00", "1990-05-01T00:00:00", "1990-05-02T00:00:00", "1990-05-03T00:00:00", "1990-05-04T00:00:00", "1990-05-07T00:00:00", "1990-05-08T00:00:00", "1990-05-09T00:00:00", "1990-05-10T00:00:00", "1990-05-11T00:00:00", "1990-05-14T00:00:00", "1990-05-15T00:00:00", "1990-05-16T00:00:00", "1990-05-17T00:00:00", "1990-05-18T00:00:00", "1990-05-21T00:00:00", "1990-05-22T00:00:00", "1990-05-23T00:00:00", "1990-05-24T00:00:00", "1990-05-25T00:00:00", "1990-05-29T00:00:00", "1990-05-30T00:00:00", "1990-05-31T00:00:00", "1990-06-01T00:00:00", "1990-06-04T00:00:00", "1990-06-05T00:00:00", "1990-06-06T00:00:00", "1990-06-07T00:00:00", "1990-06-08T00:00:00", "1990-06-11T00:00:00", "1990-06-12T00:00:00", "1990-06-13T00:00:00", "1990-06-14T00:00:00", "1990-06-15T00:00:00", "1990-06-18T00:00:00", "1990-06-19T00:00:00", "1990-06-20T00:00:00", "1990-06-21T00:00:00", "1990-06-22T00:00:00", "1990-06-25T00:00:00", "1990-06-26T00:00:00", "1990-06-27T00:00:00", "1990-06-28T00:00:00", "1990-06-29T00:00:00", "1990-07-02T00:00:00", "1990-07-03T00:00:00", "1990-07-05T00:00:00", "1990-07-06T00:00:00", "1990-07-09T00:00:00", "1990-07-10T00:00:00", "1990-07-11T00:00:00", "1990-07-12T00:00:00", "1990-07-13T00:00:00", "1990-07-16T00:00:00", "1990-07-17T00:00:00", "1990-07-18T00:00:00", "1990-07-19T00:00:00", "1990-07-20T00:00:00", "1990-07-23T00:00:00", "1990-07-24T00:00:00", "1990-07-25T00:00:00", "1990-07-26T00:00:00", "1990-07-27T00:00:00", "1990-07-30T00:00:00", "1990-07-31T00:00:00", "1990-08-01T00:00:00", "1990-08-02T00:00:00", "1990-08-03T00:00:00", "1990-08-06T00:00:00", "1990 ...

# %% [markdown]
# # 9 - Anomalies on Test Set

# %%
anomaly_vix_test = model_VIX.get_anomaly_prediction_df(X_test,set_type='test',THRESHOLD=.12,TIME_STEPS=2,is_spx=False)
plt.plot_loss_tresshold(anomaly_vix_test)
plt.plot_anomalies(anomaly_vix_test,secondary_y='close_spx')
# Out:
# Index([], dtype='object')
# <div>                            <div id="e5067434-7f16-4f70-9523-9d0239ccddd8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e5067434-7f16-4f70-9523-9d0239ccddd8")) {                    Plotly.newPlot(                        "e5067434-7f16-4f70-9523-9d0239ccddd8",                        [{"mode": "lines", "name": "error", "type": "scatter", "x": ["2017-01-31T00:00:00", "2017-02-01T00:00:00", "2017-02-02T00:00:00", "2017-02-03T00:00:00", "2017-02-06T00:00:00", "2017-02-07T00:00:00", "2017-02-08T00:00:00", "2017-02-09T00:00:00", "2017-02-10T00:00:00", "2017-02-13T00:00:00", "2017-02-14T00:00:00", "2017-02-15T00:00:00", "2017-02-16T00:00:00", "2017-02-17T00:00:00", "2017-02-21T00:00:00", "2017-02-22T00:00:00", "2017-02-23T00:00:00", "2017-02-24T00:00:00", "2017-02-27T00:00:00", "2017-02-28T00:00:00", "2017-03-01T00:00:00", "2017-03-02T00:00:00", "2017-03-03T00:00:00", "2017-03-06T00:00:00", "2017-03-07T00:00:00", "2017-03-08T00:00:00", "2017-03-09T00:00:00", "2017-03-10T00:00:00", "2017-03-13T00:00:00", "2017-03-14T00:00:00", "2017-03-15T00:00:00", "2017-03-16T00:00:00", "2017-03-17T00:00:00", "2017-03-20T00:00:00", "2017-03-21T00:00:00", "2017-03-22T00:00:00", "2017-03-23T00:00:00", "2017-03-24T00:00:00", "2017-03-27T00:00:00", "2017-03-28T00:00:00", "2017-03-29T00:00:00", "2017-03-30T00:00:00", "2017-03-31T00:00:00", "2017-04-03T00:00:00", "2017-04-04T00:00:00", "2017-04-05T00:00:00", "2017-04-06T00:00:00", "2017-04-07T00:00:00", "2017-04-10T00:00:00", "2017-04-11T00:00:00", "2017-04-12T00:00:00", "2017-04-13T00:00:00", "2017-04-17T00:00:00", "2017-04-18T00:00:00", "2017-04-19T00:00:00", "2017-04-20T00:00:00", "2017-04-21T00:00:00", "2017-04-24T00:00:00", "2017-04-25T00:00:00", "2017-04-26T00:00:00", "2017-04-27T00:00:00", "2017-04-28T00:00:00", "2017-05-01T00:00:00", "2017-05-02T00:00:00", "2017-05-03T00:00:00", "2017-05-04T00:00:00", "2017-05-05T00:00:00", "2017-05-08T00:00:00", "2017-05-09T00:00:00", "2017-05-10T00:00:00", "2017-05-11T00:00:00", "2017-05-12T00:00:00", "2017-05-15T00:00:00", "2017-05-16T00:00:00", "2017-05-17T00:00:00", "2017-05-18T00:00:00", "2017-05-19T00:00:00", "2017-05-22T00:00:00", "2017-05-23T00:00:00", "2017-05-24T00:00:00", "2017-05-25T00:00:00", "2017-05-26T00:00:00", "2017-05-30T00:00:00", "2017-05-31T00:00:00", "2017-06-01T00:00:00", "2017-06-02T00:00:00", "2017-06-05T00:00:00", "2017-06-06T00:00:00", "2017-06-07T00:00:00", "2017-06-08T00:00:00", "2017-06-09T00:00:00", "2017-06-12T00:00:00", "2017-06-13T00:00:00", "2017-06-14T00:00:00", "2017-06-15T00:00:00", "2017-06-16T00:00:00", "2017-06-19T00:00:00", "2017-06-20T00:00:00", "2017-06-21T00:00:00", "2017-06-22T00:00:00", "2017-06-23T00:00:00", "2017-06-26T00:00:00", "2017-06-27T00:00:00", "2017-06-28T00:00:00", "2017-06-29T00:00:00", "2017-06-30T00:00:00", "2017-07-03T00:00:00", "2017-07-05T00:00:00", "2017-07-06T00:00:00", "2017-07-07T00:00:00", "2017-07-10T00:00:00", "2017-07-11T00:00:00", "2017-07-12T00:00:00", "2017-07-13T00:00:00", "2017-07-14T00:00:00", "2017-07-17T00:00:00", "2017-07-18T00:00:00", "2017-07-19T00:00:00", "2017-07-20T00:00:00", "2017-07-21T00:00:00", "2017-07-24T00:00:00", "2017-07-25T00:00:00", "2017-07-26T00:00:00", "2017-07-27T00:00:00", "2017-07-28T00:00:00", "2017-07-31T00:00:00", "2017-08-01T00:00:00", "2017-08-02T00:00:00", "2017-08-03T00:00:00", "2017-08-04T00:00:00", "2017-08-07T00:00:00", "2017-08-08T00:00:00", "2017-08-09T00:00:00", "2017-08-10T00:00:00", "2017-08-11T00:00:00", "2017-08-14T00:00:00", "2017-08-15T00:00:00", "2017-08-16T00:00:00", "2017-08-17T00:00:00", "2017-08-18T00:00:00", "2017-08-21T00:00:00", "2017-08-22T00:00:00", "2017-08-23T00:00:00", "2017-08-24T00:00:00", "2017-08-25T00:00:00", "2017-08-28T00:00:00", "2017-08-29T00:00:00", "2017-08-30T00:00:00", "2017 ...
# <div>                            <div id="e9883f51-2221-4c5e-9278-f77dbea87de9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e9883f51-2221-4c5e-9278-f77dbea87de9")) {                    Plotly.newPlot(                        "e9883f51-2221-4c5e-9278-f77dbea87de9",                        [{"mode": "lines", "name": "close", "type": "scatter", "x": ["2017-01-31T00:00:00", "2017-02-01T00:00:00", "2017-02-02T00:00:00", "2017-02-03T00:00:00", "2017-02-06T00:00:00", "2017-02-07T00:00:00", "2017-02-08T00:00:00", "2017-02-09T00:00:00", "2017-02-10T00:00:00", "2017-02-13T00:00:00", "2017-02-14T00:00:00", "2017-02-15T00:00:00", "2017-02-16T00:00:00", "2017-02-17T00:00:00", "2017-02-21T00:00:00", "2017-02-22T00:00:00", "2017-02-23T00:00:00", "2017-02-24T00:00:00", "2017-02-27T00:00:00", "2017-02-28T00:00:00", "2017-03-01T00:00:00", "2017-03-02T00:00:00", "2017-03-03T00:00:00", "2017-03-06T00:00:00", "2017-03-07T00:00:00", "2017-03-08T00:00:00", "2017-03-09T00:00:00", "2017-03-10T00:00:00", "2017-03-13T00:00:00", "2017-03-14T00:00:00", "2017-03-15T00:00:00", "2017-03-16T00:00:00", "2017-03-17T00:00:00", "2017-03-20T00:00:00", "2017-03-21T00:00:00", "2017-03-22T00:00:00", "2017-03-23T00:00:00", "2017-03-24T00:00:00", "2017-03-27T00:00:00", "2017-03-28T00:00:00", "2017-03-29T00:00:00", "2017-03-30T00:00:00", "2017-03-31T00:00:00", "2017-04-03T00:00:00", "2017-04-04T00:00:00", "2017-04-05T00:00:00", "2017-04-06T00:00:00", "2017-04-07T00:00:00", "2017-04-10T00:00:00", "2017-04-11T00:00:00", "2017-04-12T00:00:00", "2017-04-13T00:00:00", "2017-04-17T00:00:00", "2017-04-18T00:00:00", "2017-04-19T00:00:00", "2017-04-20T00:00:00", "2017-04-21T00:00:00", "2017-04-24T00:00:00", "2017-04-25T00:00:00", "2017-04-26T00:00:00", "2017-04-27T00:00:00", "2017-04-28T00:00:00", "2017-05-01T00:00:00", "2017-05-02T00:00:00", "2017-05-03T00:00:00", "2017-05-04T00:00:00", "2017-05-05T00:00:00", "2017-05-08T00:00:00", "2017-05-09T00:00:00", "2017-05-10T00:00:00", "2017-05-11T00:00:00", "2017-05-12T00:00:00", "2017-05-15T00:00:00", "2017-05-16T00:00:00", "2017-05-17T00:00:00", "2017-05-18T00:00:00", "2017-05-19T00:00:00", "2017-05-22T00:00:00", "2017-05-23T00:00:00", "2017-05-24T00:00:00", "2017-05-25T00:00:00", "2017-05-26T00:00:00", "2017-05-30T00:00:00", "2017-05-31T00:00:00", "2017-06-01T00:00:00", "2017-06-02T00:00:00", "2017-06-05T00:00:00", "2017-06-06T00:00:00", "2017-06-07T00:00:00", "2017-06-08T00:00:00", "2017-06-09T00:00:00", "2017-06-12T00:00:00", "2017-06-13T00:00:00", "2017-06-14T00:00:00", "2017-06-15T00:00:00", "2017-06-16T00:00:00", "2017-06-19T00:00:00", "2017-06-20T00:00:00", "2017-06-21T00:00:00", "2017-06-22T00:00:00", "2017-06-23T00:00:00", "2017-06-26T00:00:00", "2017-06-27T00:00:00", "2017-06-28T00:00:00", "2017-06-29T00:00:00", "2017-06-30T00:00:00", "2017-07-03T00:00:00", "2017-07-05T00:00:00", "2017-07-06T00:00:00", "2017-07-07T00:00:00", "2017-07-10T00:00:00", "2017-07-11T00:00:00", "2017-07-12T00:00:00", "2017-07-13T00:00:00", "2017-07-14T00:00:00", "2017-07-17T00:00:00", "2017-07-18T00:00:00", "2017-07-19T00:00:00", "2017-07-20T00:00:00", "2017-07-21T00:00:00", "2017-07-24T00:00:00", "2017-07-25T00:00:00", "2017-07-26T00:00:00", "2017-07-27T00:00:00", "2017-07-28T00:00:00", "2017-07-31T00:00:00", "2017-08-01T00:00:00", "2017-08-02T00:00:00", "2017-08-03T00:00:00", "2017-08-04T00:00:00", "2017-08-07T00:00:00", "2017-08-08T00:00:00", "2017-08-09T00:00:00", "2017-08-10T00:00:00", "2017-08-11T00:00:00", "2017-08-14T00:00:00", "2017-08-15T00:00:00", "2017-08-16T00:00:00", "2017-08-17T00:00:00", "2017-08-18T00:00:00", "2017-08-21T00:00:00", "2017-08-22T00:00:00", "2017-08-23T00:00:00", "2017-08-24T00:00:00", "2017-08-25T00:00:00", "2017-08-28T00:00:00", "2017-08-29T00:00:00", "2017-08-30T00:00:00", "2017 ...

# %% [markdown]
# # 10 - Analysis of anomalies' dates

# %% [markdown]
# ## Detected on train set

# %%
anomaly_sp500_train[anomaly_sp500_train.anomaly==True]
anomaly_sp500_train['date']=anomaly_sp500_train.index
anomaly_sp500_train['event'] = anomaly_sp500_train.date.apply(lambda d :'https://www.onthisday.com/date/%d/%s/%d'%(d.year,calendar.month_name[d.month],d.day))
#anomaly_sp500_train['event'] = anomaly_sp500_train.date.apply(lambda d :'https://www.nytimes.com/%d/%d/%d/business'%(d.year,d.month,d.day))
#https://www.onthisday.com/date/1990/august/28
anomaly_sp500_train[anomaly_sp500_train.anomaly==True].head(20)

# %%
anomaly_sp500_train#.date.iloc[0].day

# %% [markdown]
# 7/8/1990 - https://www.onthisday.com/date/1990/august/7

# %% [markdown]
# ## Black Monday - October 1987
# Black Monday is used most often to refer to the second-largest one-day percentage drop in stock market history. It occurred on Oct. 19, 1987, when the Dow Jones Industrial Average dropped 22.61%, falling 508 points to 1738.74. The S&P 500 fell 20.4%, dropping 57.64 points to 225.06. It took two years for the Dow to regain this loss.1
#
#
# ## Black Monday - August 2015
# On Aug. 24, 2015, the Dow fell 1,089 points to 15,370.33, as soon as the market opened. It was a 16% drop from its May 19 high of 18,312.39. It quickly recovered and closed just 533 points below the open. A 10% drop makes it a market correction, not a crash. It followed a 531-point drop the previous Friday.6
#
# ﻿ Both were caused by worries about slower economic growth in China and uncertainty over its yuan devaluation.
#
#
# ## 7 August 1990
# US deploys troops to Saudi Arabia beginning Operation Desert Shield after Iraq invaded Kuwait.
#
# ## 24 August 1990
# Iraqi troops surround US & other embassies in Kuwait City
#
# ## 27 october 1997 mini-crash
# https://en.wikipedia.org/wiki/October_27,_1997,_mini-crash
#
#
# ## 27-28 August 1998
# had the Russian debt crisis and Long-Term Capital Management (LTCM) collapse;
#
# ## 10 Mar 2000
# Dot-com bubble, Collapse of a technology bubble.
#
# ## 11 Sep 2001 (not detected)
#
# ## 16 Sep 2008 Financial crisis of 2007–08
#
# ## 	6 May 2010
# 2010 flash crash
#
# ## August 2011
# gave us the U.S. debt downgrade;
#
# #FEBRUARY 5, 2018 (not detected)
#  - Wall Street plunges, S&P 500 erases 2018's gains
# > https://www.reuters.com/article/us-usa-stocks-idUSKBN1FP1OR

# %% [markdown]
# # 9 - Conclusion

# %% [markdown]
# The model seems to detect anomaly on the period of huge peak of the VIX, hence enabling to detect major crisis and events.
#
# More investigation could be done on the anomalies' date to further asess the relevance of the model.

# %% [markdown]
# # Annex

# %% [markdown]
# ## Links on Stationarity
# > https://www.youtube.com/watch?v=aIdTGKjQWjA
#
# > https://www.youtube.com/watch?v=oY-j2Wof51c
#
# > https://www.youtube.com/watch?v=ca0rDWo7IpI
#
# > https://www.youtube.com/watch?v=CyHKQQRXfww
#
# > https://www.youtube.com/watch?v=e8Yw4alG16Q
#
# > https://www.youtube.com/watch?v=SJHVyn3UbWc
#
# > https://towardsdatascience.com/timeseries-data-munging-lagging-variables-that-are-distributed-across-multiple-groups-86e0a038460c
#
# > https://jasdeep06.github.io/posts/Understanding-LSTM-in-Tensorflow-MNIST/

# %% [markdown]
# ## NN, LSTM Parameters
#
# > http://colah.github.io/posts/2015-08-Understanding-LSTMs/
#
# > https://stats.stackexchange.com/questions/365428/difference-between-a-single-unit-lstm-and-3-unit-lstm-neural-network/365600

# %% [markdown]
# ## Links to help finding the best parameters
# > https://www.youtube.com/watch?v=6S2v7G-OupA
#
# > https://www.renom.jp/notebooks/tutorial/time_series/lstm-anomalydetection/notebook.html
#
# > https://www.youtube.com/watch?v=LfnrRPFhkuY
#
# > https://www.youtube.com/watch?v=Y2wfIKQyd1I
#
# > https://medium.com/quantitative-investing/machine-learning-project-is-lstm-able-to-predict-the-stock-market-f21ce9106182
#
# > Volatility predicting
# https://www.learningmarkets.com/predicting-volatility-with-the-vix/

# %% [markdown]
# # Available Optimizers :
#
# > https://www.tensorflow.org/api_docs/python/tf/keras/optimizers
#
# * Adadelta : KO, higher mae than Adam
# * Adagrade : KO, longer to converge with higher mae than Adam
# * Adamax : KO, longer to converge with higher mae than Adam
# * Ftrl : KO, longer to converge with higher mae than Adam
# * Nadam : same result than Adam
# * RMSProp : same result than Adam
# * SGD : same result than Adam

# %% [markdown]
# https://www.youtube.com/channel/UC34rW-HtPJulxr5wp2Xa04w

# %%
#https://www.pyimagesearch.com/2020/02/17/autoencoders-with-keras-tensorflow-and-deep-learning/
